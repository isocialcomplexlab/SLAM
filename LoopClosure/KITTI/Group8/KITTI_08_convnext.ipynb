# %%
from torch import nn
import torch.nn.functional as F
import numpy as np
import torchvision
import torchvision.models as models
from torchvision import datasets
import torchvision.transforms as transforms
from torchvision.transforms.functional import crop
import cv2
import matplotlib.pyplot as plt
import time
import torch

# %%
def crop_r(image):
    return crop(image, 4, 124, 124, 124)
    
def crop_l(image):
    return crop(image, 4, 4, 124, 124)  
    
transform_right = transforms.Compose(
    [
        transforms.Resize((256,256)),
        #transforms.RandomRotation(10),
        transforms.Lambda(crop_r),
        transforms.ToTensor(),
        transforms.Normalize((0.36, 0.36, 0.36), (0.28, 0.28, 0.28))
    ])
transform_left = transforms.Compose(
    [
        transforms.Resize((256,256)),
        #transforms.RandomRotation(10),
        transforms.Lambda(crop_l),
        transforms.ToTensor(),
        transforms.Normalize((0.36, 0.36, 0.36), (0.28, 0.28, 0.28))
    ])

# %%
train_path = '/content/drive/MyDrive/Datasets/KITTI/08'
batch_size = 1

train_r = datasets.ImageFolder(train_path, transform_right)
train_l = datasets.ImageFolder(train_path, transform_left)

train_loader_r = torch.utils.data.DataLoader(train_r, batch_size)
train_loader_l = torch.utils.data.DataLoader(train_l, batch_size)

# %%
weights = models.ConvNeXt_Base_Weights
model = models.convnext_base(weights=weights)
# Out:
# /usr/local/lib/python3.8/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ConvNeXt_Base_Weights.IMAGENET1K_V1`. You can also use `weights=ConvNeXt_Base_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %%
def rightpt(train_loader_r, min_, max_, aux_):
  for i, data in enumerate(train_loader_r):
      if i > min_:
        inputs, labels = data
        outputs = model.classifier[0](model.avgpool(model.features(inputs)))
        output_.append(outputs)
        if i > max_:
          return output_

# %%
def leftpt(train_loader_l, min_, max_, aux_,output_):
  for i,data in enumerate(train_loader_l):
    if i > min_:
      inputs, labels = data
      outputs = model.classifier[0](model.avgpool(model.features(inputs)))
      output_[i-aux_] = torch.cat((output_[i-aux_], outputs), 1)
      if i > max_:
          return output_

# %%
for n_it in range(1,166):
  output_ = []
  output_new = []
  try:
    if n_it == 1:
      min_ = 0
    else:
      min_ = (n_it-1)*50
    max_ = n_it*50
    aux_ = min_ +1
    output_ = rightpt(train_loader_r, min_, max_, aux_)
    output_new = leftpt(train_loader_l, min_, max_, aux_, output_)
    out_path = '/content/drive/MyDrive/Datasets/tensors_kitti_08_convnext/tensors'+str(n_it)+'.pt'
    torch.save(output_new,out_path)
  except:
    print('error')

# %%
def match(cam_img, db_img, dist_limit):
    distance = torch.cdist(cam_img, db_img, p=2)
    max_dist = torch.max(distance)
    if max_dist <= dist_limit:
        return True
    
    return False

# %%
def belief_generation(db, descriptor):
    belief = []
    lp = 0
    for d in db:
        bg = match(descriptor, d, 1.8)
        if bg:
            belief.append(1)
        else:
            belief = []
        if len(belief) >= 3:
            print('loop')
            print(d)
            lp += 1
    return lp

# %%
database = [database1,database2,database3,database4,database5,database6,database7,database8,database9,database10,
            database11,database12,database13,database14,database15,database16,database17,database18,database19,database20,
            database21,database22,database23,database24,database25,database26,database27,database28,database29,database30,
            database31,database32,database33,database34,database35,database36,database37,database38,database39,database40,
            database41,database42,database43,database44,database45,database46,database47,database48,database49,database50,
            database51,database52,database53,database54,database55,database56,database57,database58,database59,database60,
            database61,database62,database63,database64,database65,database66,database67,database68,database69,database70,
            database71,database72,database73,database74,database75,database76,database77,database78,database79,database80,
            database81,database82,database83,database84,database85,database86,database87,database88,database89,database90,
            database91,database92,database93,database94,database95,database96,database97,database98,database99,database100,
            database101,database102,database103,database104,database105,database106,database107,database108,database109,database110,
            database111,database112,database113,database114,database115,database116,database117,database118,database119,database120,
            database121,database122,database123,database124,database125,database126,database127,database128,database129,database130,
            database131,database132,database133,database134,database135,database136,database137,database138,database139,database140,
            database141,database142,database143]

d = []

# %%
co = 0
for bg in database:

  for i,data in enumerate(bg):
    if i < 3:
      d.append(data)
    else:
      loop_ = belief_generation(d, data)
      with open('/content/drive/MyDrive/Datasets/KITTI/loop_kitti_08_convnext_v1.txt', 'a') as txt_file:
        if loop_ > 0:
          txt_file.write('Found loop')
          image_number = round(((co*50)+i)/2,0)
          txt_file.write('\n image: '+str(image_number))
          txt_file.write('\n')
        else:
          d.append(data)
  co += 1
# Out:
# A saída de streaming foi truncada nas últimas 5000 linhas.
#
#          [[-0.1977]]]], requires_grad=True)
# loop
# tensor([[[[-0.0074]],
#
#          [[-0.2606]],
#
#          [[-0.3285]],
#
#          ...,
#
#          [[ 0.2064]],
#
#          [[ 0.2112]],
#
#          [[-0.1977]]]], requires_grad=True)
# loop
# tensor([[[[-0.0074]],
#
#          [[-0.2606]],
#
#          [[-0.3285]],
#
#          ...,
#
#          [[ 0.2064]],
#
#          [[ 0.2112]],
#
#          [[-0.1977]]]], requires_grad=True)
# loop
# tensor([[[[-0.1562]],
#
#          [[-0.2957]],
#
#          [[-0.0143]],
#
#          ...,
#
#          [[-0.0998]],
#
#          [[ 0.1099]],
#
#          [[-0.3756]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0465]],
#
#          [[ 0.1225]],
#
#          [[-0.0990]],
#
#          ...,
#
#          [[ 0.0992]],
#
#          [[ 0.0586]],
#
#          [[ 0.3627]]]], requires_grad=True)
# loop
# tensor([[[[-0.6066]],
#
#          [[-0.0702]],
#
#          [[ 0.0077]],
#
#          ...,
#
#          [[-0.1478]],
#
#          [[ 0.8319]],
#
#          [[-0.0061]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2505]],
#
#          [[-0.2900]],
#
#          [[ 0.1718]],
#
#          ...,
#
#          [[ 0.2655]],
#
#          [[ 0.4416]],
#
#          [[ 0.2432]]]], requires_grad=True)
# loop
# tensor([[[[-0.1095]],
#
#          [[-0.2889]],
#
#          [[-0.0453]],
#
#          ...,
#
#          [[ 0.4032]],
#
#          [[ 0.4119]],
#
#          [[-0.1213]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1418]],
#
#          [[-0.1590]],
#
#          [[-0.0623]],
#
#          ...,
#
#          [[ 0.4642]],
#
#          [[ 0.3597]],
#
#          [[ 0.0610]]]], requires_grad=True)
# loop
# tensor([[[[-0.0288]],
#
#          [[-0.2828]],
#
#          [[ 0.0237]],
#
#          ...,
#
#          [[ 0.3959]],
#
#          [[ 0.3468]],
#
#          [[ 0.2028]]]], requires_grad=True)
# loop
# tensor([[[[-0.1095]],
#
#          [[-0.2889]],
#
#          [[-0.0453]],
#
#          ...,
#
#          [[ 0.4032]],
#
#          [[ 0.4119]],
#
#          [[-0.1213]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1418]],
#
#          [[-0.1590]],
#
#          [[-0.0623]],
#
#          ...,
#
#          [[ 0.4642]],
#
#          [[ 0.3597]],
#
#          [[ 0.0610]]]], requires_grad=True)
# loop
# tensor([[[[-0.3638]],
#
#          [[-0.7396]],
#
#          [[-0.1172]],
#
#          ...,
#
#          [[ 0.3605]],
#
#          [[ 0.3331]],
#
#          [[-0.2591]]]], requires_grad=True)
# loop
# tensor([[[[-0.0288]],
#
#          [[-0.2828]],
#
#          [[ 0.0237]],
#
#          ...,
#
#          [[ 0.3959]],
#
#          [[ 0.3468]],
#
#          [[ 0.2028]]]], requires_grad=True)
# loop
# tensor([[[[-0.1095]],
#
#          [[-0.2889]],
#
#          [[-0.0453]],
#
#          ...,
#
#          [[ 0.4032]],
#
#          [[ 0.4119]],
#
#          [[-0.1213]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1418]],
#
#          [[-0.1590]],
#
#          [[-0.0623]],
#
#          ...,
#
#          [[ 0.4642]],
#
#          [[ 0.3597]],
#
#          [[ 0.0610]]]], requires_grad=True)
# loop
# tensor([[[[-0.3638]],
#
#          [[-0.7396]],
#
#          [[-0.1172]],
#
#          ...,
#
#          [[ 0.3605]],
#
#          [[ 0.3331]],
#
#          [[-0.2591]]]], requires_grad=True)
# loop
# tensor([[[[-0.0288]],
#
#          [[-0.2828]],
#
#          [[ 0.0237]],
#
#          ...,
#
#          [[ 0.3959]],
#
#          [[ 0.3468]],
#
#          [[ 0.2028]]]], requires_grad=True)
# loop
# tensor([[[[-0.1095]],
#
#          [[-0.2889]],
#
#          [[-0.0453]],
#
#          ...,
#
#          [[ 0.4032]],
#
#          [[ 0.4119]],
#
#          [[-0.1213]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1418]],
#
#          [[-0.1590]],
#
#          [[-0.0623]],
#
#          ...,
#
#          [[ 0.4642]],
#
#          [[ 0.3597]],
#
#          [[ 0.0610]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1214]],
#
#          [[-0.3367]],
#
#          [[ 0.1225]],
#
#          ...,
#
#          [[ 0.2086]],
#
#          [[ 0.4174]],
#
#          [[ 0.1911]]]], requires_grad=True)
# loop
# tensor([[[[-0.4024]],
#
#          [[-0.1827]],
#
#          [[ 0.2295]],
#
#          ...,
#
#          [[ 0.4546]],
#
#          [[ 0.4133]],
#
#          [[ 0.4059]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1214]],
#
#          [[-0.3367]],
#
#          [[ 0.1225]],
#
#          ...,
#
#          [[ 0.2086]],
#
#          [[ 0.4174]],
#
#          [[ 0.1911]]]], requires_grad=True)
# loop
# tensor([[[[-0.3674]],
#
#          [[-0.2661]],
#
#          [[-0.2958]],
#
#          ...,
#
#          [[ 0.4966]],
#
#          [[ 0.5828]],
#
#          [[ 0.0852]]]], requires_grad=True)
# loop
# tensor([[[[-0.6071]],
#
#          [[-0.2219]],
#
#          [[-0.0896]],
#
#          ...,
#
#          [[ 0.2817]],
#
#          [[ 0.3121]],
#
#          [[ 0.2941]]]], requires_grad=True)
# loop
# tensor([[[[-0.1973]],
#
#          [[-0.6169]],
#
#          [[ 0.1392]],
#
#          ...,
#
#          [[ 0.3572]],
#
#          [[ 0.4310]],
#
#          [[ 0.0732]]]], requires_grad=True)
# loop
# tensor([[[[-0.4024]],
#
#          [[-0.1827]],
#
#          [[ 0.2295]],
#
#          ...,
#
#          [[ 0.4546]],
#
#          [[ 0.4133]],
#
#          [[ 0.4059]]]], requires_grad=True)
# loop
# tensor([[[[-0.4024]],
#
#          [[-0.1827]],
#
#          [[ 0.2295]],
#
#          ...,
#
#          [[ 0.4546]],
#
#          [[ 0.4133]],
#
#          [[ 0.4059]]]], requires_grad=True)
# loop
# tensor([[[[-0.0296]],
#
#          [[-0.3093]],
#
#          [[-0.1743]],
#
#          ...,
#
#          [[ 0.3760]],
#
#          [[ 0.1908]],
#
#          [[ 0.0421]]]], requires_grad=True)
# loop
# tensor([[[[-0.2679]],
#
#          [[-0.2595]],
#
#          [[ 0.4292]],
#
#          ...,
#
#          [[ 0.6714]],
#
#          [[ 0.4545]],
#
#          [[ 0.4468]]]], requires_grad=True)
# loop
# tensor([[[[-0.0296]],
#
#          [[-0.3093]],
#
#          [[-0.1743]],
#
#          ...,
#
#          [[ 0.3760]],
#
#          [[ 0.1908]],
#
#          [[ 0.0421]]]], requires_grad=True)
# loop
# tensor([[[[-0.1106]],
#
#          [[-0.0479]],
#
#          [[ 0.3951]],
#
#          ...,
#
#          [[ 0.3337]],
#
#          [[ 0.3070]],
#
#          [[-0.0059]]]], requires_grad=True)
# loop
# tensor([[[[-0.2679]],
#
#          [[-0.2595]],
#
#          [[ 0.4292]],
#
#          ...,
#
#          [[ 0.6714]],
#
#          [[ 0.4545]],
#
#          [[ 0.4468]]]], requires_grad=True)
# loop
# tensor([[[[-0.1853]],
#
#          [[-0.0180]],
#
#          [[ 0.0686]],
#
#          ...,
#
#          [[ 0.4522]],
#
#          [[ 0.7156]],
#
#          [[ 0.3769]]]], requires_grad=True)
# loop
# tensor([[[[-0.4024]],
#
#          [[-0.1827]],
#
#          [[ 0.2295]],
#
#          ...,
#
#          [[ 0.4546]],
#
#          [[ 0.4133]],
#
#          [[ 0.4059]]]], requires_grad=True)
# loop
# tensor([[[[-0.2070]],
#
#          [[-0.6556]],
#
#          [[ 0.2289]],
#
#          ...,
#
#          [[ 0.4068]],
#
#          [[ 0.5347]],
#
#          [[-0.4446]]]], requires_grad=True)
# loop
# tensor([[[[-0.6682]],
#
#          [[ 0.0706]],
#
#          [[-0.4099]],
#
#          ...,
#
#          [[ 0.4759]],
#
#          [[ 0.3695]],
#
#          [[ 0.0592]]]], requires_grad=True)
# loop
# tensor([[[[-0.2070]],
#
#          [[-0.6556]],
#
#          [[ 0.2289]],
#
#          ...,
#
#          [[ 0.4068]],
#
#          [[ 0.5347]],
#
#          [[-0.4446]]]], requires_grad=True)
# loop
# tensor([[[[-0.0423]],
#
#          [[-0.9682]],
#
#          [[-0.7146]],
#
#          ...,
#
#          [[ 0.9652]],
#
#          [[ 0.7845]],
#
#          [[-0.1096]]]], requires_grad=True)
# loop
# tensor([[[[-0.1973]],
#
#          [[-0.6169]],
#
#          [[ 0.1392]],
#
#          ...,
#
#          [[ 0.3572]],
#
#          [[ 0.4310]],
#
#          [[ 0.0732]]]], requires_grad=True)
# loop
# tensor([[[[-0.0296]],
#
#          [[-0.3093]],
#
#          [[-0.1743]],
#
#          ...,
#
#          [[ 0.3760]],
#
#          [[ 0.1908]],
#
#          [[ 0.0421]]]], requires_grad=True)
# loop
# tensor([[[[-0.0123]],
#
#          [[-0.0547]],
#
#          [[ 0.0031]],
#
#          ...,
#
#          [[ 0.4731]],
#
#          [[ 0.4637]],
#
#          [[-0.3204]]]], requires_grad=True)
# loop
# tensor([[[[-0.3134]],
#
#          [[-0.2547]],
#
#          [[ 0.3974]],
#
#          ...,
#
#          [[ 0.3382]],
#
#          [[ 0.4709]],
#
#          [[ 0.1991]]]], requires_grad=True)
# loop
# tensor([[[[-0.3001]],
#
#          [[-0.3003]],
#
#          [[ 0.4394]],
#
#          ...,
#
#          [[ 0.4427]],
#
#          [[ 0.4608]],
#
#          [[ 0.5244]]]], requires_grad=True)
# loop
# tensor([[[[-0.1106]],
#
#          [[-0.0479]],
#
#          [[ 0.3951]],
#
#          ...,
#
#          [[ 0.3337]],
#
#          [[ 0.3070]],
#
#          [[-0.0059]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0219]],
#
#          [[-0.2078]],
#
#          [[-0.2288]],
#
#          ...,
#
#          [[ 0.3027]],
#
#          [[ 0.4300]],
#
#          [[ 0.1703]]]], requires_grad=True)
# loop
# tensor([[[[-0.3001]],
#
#          [[-0.3003]],
#
#          [[ 0.4394]],
#
#          ...,
#
#          [[ 0.4427]],
#
#          [[ 0.4608]],
#
#          [[ 0.5244]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0589]],
#
#          [[-0.2873]],
#
#          [[ 0.0791]],
#
#          ...,
#
#          [[ 0.2272]],
#
#          [[ 0.3729]],
#
#          [[ 0.5335]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1773]],
#
#          [[-0.1238]],
#
#          [[ 0.3474]],
#
#          ...,
#
#          [[ 0.2780]],
#
#          [[ 0.4153]],
#
#          [[ 0.0517]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0219]],
#
#          [[-0.2078]],
#
#          [[-0.2288]],
#
#          ...,
#
#          [[ 0.3027]],
#
#          [[ 0.4300]],
#
#          [[ 0.1703]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4046]],
#
#          [[-0.2662]],
#
#          [[-0.3738]],
#
#          ...,
#
#          [[ 0.3153]],
#
#          [[ 0.2980]],
#
#          [[-0.2965]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1442]],
#
#          [[-0.2354]],
#
#          [[-0.0853]],
#
#          ...,
#
#          [[ 0.3915]],
#
#          [[ 0.4651]],
#
#          [[-0.6832]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1161]],
#
#          [[-0.5831]],
#
#          [[-0.3897]],
#
#          ...,
#
#          [[ 0.5050]],
#
#          [[ 0.4613]],
#
#          [[-0.6284]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0033]],
#
#          [[-0.7408]],
#
#          [[-0.3500]],
#
#          ...,
#
#          [[ 0.5476]],
#
#          [[ 0.4135]],
#
#          [[-0.2670]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1161]],
#
#          [[-0.5831]],
#
#          [[-0.3897]],
#
#          ...,
#
#          [[ 0.5050]],
#
#          [[ 0.4613]],
#
#          [[-0.6284]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3572]],
#
#          [[-0.4801]],
#
#          [[ 0.5008]],
#
#          ...,
#
#          [[ 0.2667]],
#
#          [[ 0.1968]],
#
#          [[ 0.5820]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3572]],
#
#          [[-0.4801]],
#
#          [[ 0.5008]],
#
#          ...,
#
#          [[ 0.2667]],
#
#          [[ 0.1968]],
#
#          [[ 0.5820]]]], requires_grad=True)
# loop
# tensor([[[[-0.0970]],
#
#          [[-0.3440]],
#
#          [[ 0.9390]],
#
#          ...,
#
#          [[ 0.4017]],
#
#          [[ 0.1803]],
#
#          [[ 0.7158]]]], requires_grad=True)
# loop
# tensor([[[[-0.0970]],
#
#          [[-0.3440]],
#
#          [[ 0.9390]],
#
#          ...,
#
#          [[ 0.4017]],
#
#          [[ 0.1803]],
#
#          [[ 0.7158]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0623]],
#
#          [[-0.4357]],
#
#          [[-0.0216]],
#
#          ...,
#
#          [[ 0.4872]],
#
#          [[-0.0660]],
#
#          [[ 0.2504]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2850]],
#
#          [[-0.1102]],
#
#          [[ 0.5275]],
#
#          ...,
#
#          [[ 0.1461]],
#
#          [[ 0.5036]],
#
#          [[-0.4751]]]], requires_grad=True)
# loop
# tensor([[[[-0.0250]],
#
#          [[-0.3486]],
#
#          [[ 0.3677]],
#
#          ...,
#
#          [[ 0.0268]],
#
#          [[ 0.3586]],
#
#          [[-0.6686]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0888]],
#
#          [[-0.1694]],
#
#          [[ 0.6943]],
#
#          ...,
#
#          [[ 0.0878]],
#
#          [[ 0.5848]],
#
#          [[-0.5739]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2850]],
#
#          [[-0.1102]],
#
#          [[ 0.5275]],
#
#          ...,
#
#          [[ 0.1461]],
#
#          [[ 0.5036]],
#
#          [[-0.4751]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2734]],
#
#          [[-0.4261]],
#
#          [[ 0.4592]],
#
#          ...,
#
#          [[-0.1953]],
#
#          [[ 0.5349]],
#
#          [[-0.4932]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2734]],
#
#          [[-0.4261]],
#
#          [[ 0.4592]],
#
#          ...,
#
#          [[-0.1953]],
#
#          [[ 0.5349]],
#
#          [[-0.4932]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2734]],
#
#          [[-0.4261]],
#
#          [[ 0.4592]],
#
#          ...,
#
#          [[-0.1953]],
#
#          [[ 0.5349]],
#
#          [[-0.4932]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2566]],
#
#          [[-0.1549]],
#
#          [[ 0.1878]],
#
#          ...,
#
#          [[ 0.1157]],
#
#          [[ 0.3676]],
#
#          [[-0.0804]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2926]],
#
#          [[-0.1702]],
#
#          [[ 0.1980]],
#
#          ...,
#
#          [[ 0.1749]],
#
#          [[ 0.2301]],
#
#          [[-0.0393]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1997]],
#
#          [[-0.0307]],
#
#          [[-0.0085]],
#
#          ...,
#
#          [[ 0.1152]],
#
#          [[ 0.2795]],
#
#          [[ 0.2359]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2734]],
#
#          [[-0.4261]],
#
#          [[ 0.4592]],
#
#          ...,
#
#          [[-0.1953]],
#
#          [[ 0.5349]],
#
#          [[-0.4932]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1182]],
#
#          [[ 0.2665]],
#
#          [[ 0.2586]],
#
#          ...,
#
#          [[ 0.2154]],
#
#          [[ 0.2556]],
#
#          [[-0.6426]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2866]],
#
#          [[-0.1434]],
#
#          [[ 0.5014]],
#
#          ...,
#
#          [[ 0.2436]],
#
#          [[ 0.2125]],
#
#          [[-0.1306]]]], requires_grad=True)
# loop
# tensor([[[[0.1462]],
#
#          [[0.4021]],
#
#          [[0.4588]],
#
#          ...,
#
#          [[0.3427]],
#
#          [[0.4031]],
#
#          [[0.0939]]]], requires_grad=True)
# loop
# tensor([[[[-0.1691]],
#
#          [[-0.4196]],
#
#          [[ 0.4590]],
#
#          ...,
#
#          [[ 0.4391]],
#
#          [[ 0.3766]],
#
#          [[-1.2564]]]], requires_grad=True)
# loop
# tensor([[[[-0.0296]],
#
#          [[-0.3093]],
#
#          [[-0.1743]],
#
#          ...,
#
#          [[ 0.3760]],
#
#          [[ 0.1908]],
#
#          [[ 0.0421]]]], requires_grad=True)
# loop
# tensor([[[[-0.1704]],
#
#          [[ 0.1588]],
#
#          [[ 0.3408]],
#
#          ...,
#
#          [[ 0.4193]],
#
#          [[ 0.3387]],
#
#          [[-0.6892]]]], requires_grad=True)
# loop
# tensor([[[[-0.3811]],
#
#          [[-0.0823]],
#
#          [[-0.4753]],
#
#          ...,
#
#          [[ 0.2873]],
#
#          [[ 0.2732]],
#
#          [[-1.2042]]]], requires_grad=True)
# loop
# tensor([[[[-0.6513]],
#
#          [[ 0.0339]],
#
#          [[ 0.0921]],
#
#          ...,
#
#          [[ 0.3083]],
#
#          [[ 0.2500]],
#
#          [[-1.3516]]]], requires_grad=True)
# loop
# tensor([[[[-0.3811]],
#
#          [[-0.0823]],
#
#          [[-0.4753]],
#
#          ...,
#
#          [[ 0.2873]],
#
#          [[ 0.2732]],
#
#          [[-1.2042]]]], requires_grad=True)
# loop
# tensor([[[[-0.4898]],
#
#          [[-0.4952]],
#
#          [[-0.5285]],
#
#          ...,
#
#          [[ 0.1161]],
#
#          [[ 0.1003]],
#
#          [[-0.6350]]]], requires_grad=True)
# loop
# tensor([[[[-0.7027]],
#
#          [[-0.1419]],
#
#          [[-1.2280]],
#
#          ...,
#
#          [[ 0.2573]],
#
#          [[ 0.0451]],
#
#          [[-0.8925]]]], requires_grad=True)
# loop
# tensor([[[[-0.0288]],
#
#          [[-0.9730]],
#
#          [[-0.1777]],
#
#          ...,
#
#          [[ 0.2123]],
#
#          [[ 0.4177]],
#
#          [[-0.6337]]]], requires_grad=True)
# loop
# tensor([[[[-0.4693]],
#
#          [[-0.7841]],
#
#          [[-0.3888]],
#
#          ...,
#
#          [[ 0.0112]],
#
#          [[ 0.2388]],
#
#          [[-0.2689]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4488]],
#
#          [[-0.5516]],
#
#          [[ 0.1186]],
#
#          ...,
#
#          [[ 0.1761]],
#
#          [[ 0.3206]],
#
#          [[-0.6595]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1656]],
#
#          [[-0.6646]],
#
#          [[ 0.4209]],
#
#          ...,
#
#          [[ 0.0644]],
#
#          [[ 0.1623]],
#
#          [[-0.8804]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4488]],
#
#          [[-0.5516]],
#
#          [[ 0.1186]],
#
#          ...,
#
#          [[ 0.1761]],
#
#          [[ 0.3206]],
#
#          [[-0.6595]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4006]],
#
#          [[-0.5946]],
#
#          [[-0.3164]],
#
#          ...,
#
#          [[ 0.4655]],
#
#          [[ 0.4402]],
#
#          [[-0.7280]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2432]],
#
#          [[-0.8711]],
#
#          [[-0.2575]],
#
#          ...,
#
#          [[ 0.2901]],
#
#          [[ 0.7154]],
#
#          [[-0.0249]]]], requires_grad=True)
# loop
# tensor([[[[-0.1652]],
#
#          [[-0.6722]],
#
#          [[-0.6212]],
#
#          ...,
#
#          [[ 0.3670]],
#
#          [[ 0.2151]],
#
#          [[-0.1252]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3066]],
#
#          [[-0.9147]],
#
#          [[ 0.4212]],
#
#          ...,
#
#          [[ 0.1976]],
#
#          [[ 0.4281]],
#
#          [[-0.3258]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[-0.1696]],
#
#          [[-0.5949]],
#
#          [[-0.5772]],
#
#          ...,
#
#          [[ 0.3550]],
#
#          [[ 0.2909]],
#
#          [[-0.0010]]]], requires_grad=True)
# loop
# tensor([[[[-0.3919]],
#
#          [[-0.3667]],
#
#          [[-0.1585]],
#
#          ...,
#
#          [[ 0.4210]],
#
#          [[ 0.2852]],
#
#          [[-0.7487]]]], requires_grad=True)
# loop
# tensor([[[[-0.2200]],
#
#          [[-0.6661]],
#
#          [[-0.1734]],
#
#          ...,
#
#          [[ 0.5021]],
#
#          [[ 0.5703]],
#
#          [[-0.5130]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2114]],
#
#          [[-0.6738]],
#
#          [[-0.5776]],
#
#          ...,
#
#          [[ 0.3598]],
#
#          [[ 0.3190]],
#
#          [[-0.2461]]]], requires_grad=True)
# loop
# tensor([[[[-0.1696]],
#
#          [[-0.5949]],
#
#          [[-0.5772]],
#
#          ...,
#
#          [[ 0.3550]],
#
#          [[ 0.2909]],
#
#          [[-0.0010]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1407]],
#
#          [[-0.5888]],
#
#          [[-0.8967]],
#
#          ...,
#
#          [[ 0.4771]],
#
#          [[ 0.3694]],
#
#          [[ 0.5823]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5430]],
#
#          [[-0.1488]],
#
#          [[-0.7591]],
#
#          ...,
#
#          [[ 0.3792]],
#
#          [[ 0.2334]],
#
#          [[-0.1457]]]], requires_grad=True)
# loop
# tensor([[[[-0.1696]],
#
#          [[-0.5949]],
#
#          [[-0.5772]],
#
#          ...,
#
#          [[ 0.3550]],
#
#          [[ 0.2909]],
#
#          [[-0.0010]]]], requires_grad=True)
# loop
# tensor([[[[-0.1298]],
#
#          [[-0.2325]],
#
#          [[-1.0470]],
#
#          ...,
#
#          [[ 0.3120]],
#
#          [[ 0.1395]],
#
#          [[ 0.2526]]]], requires_grad=True)
# loop
# tensor([[[[ 0.6751]],
#
#          [[-0.8247]],
#
#          [[-1.0036]],
#
#          ...,
#
#          [[ 0.4588]],
#
#          [[ 0.1037]],
#
#          [[-0.1675]]]], requires_grad=True)
# loop
# tensor([[[[-0.0742]],
#
#          [[-0.6633]],
#
#          [[-0.7053]],
#
#          ...,
#
#          [[ 0.4514]],
#
#          [[ 0.2283]],
#
#          [[ 0.4393]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2975]],
#
#          [[-1.0188]],
#
#          [[-0.3602]],
#
#          ...,
#
#          [[ 0.4944]],
#
#          [[ 0.2943]],
#
#          [[ 0.4375]]]], requires_grad=True)
# loop
# tensor([[[[-0.0135]],
#
#          [[-1.1545]],
#
#          [[-0.3377]],
#
#          ...,
#
#          [[ 0.6242]],
#
#          [[ 0.1527]],
#
#          [[ 0.4186]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0785]],
#
#          [[-0.8872]],
#
#          [[-0.2590]],
#
#          ...,
#
#          [[ 0.6460]],
#
#          [[ 0.5261]],
#
#          [[ 0.6556]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1985]],
#
#          [[-0.7252]],
#
#          [[-0.2609]],
#
#          ...,
#
#          [[ 0.5573]],
#
#          [[ 0.4146]],
#
#          [[ 0.3804]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2975]],
#
#          [[-1.0188]],
#
#          [[-0.3602]],
#
#          ...,
#
#          [[ 0.4944]],
#
#          [[ 0.2943]],
#
#          [[ 0.4375]]]], requires_grad=True)
# loop
# tensor([[[[-0.0135]],
#
#          [[-1.1545]],
#
#          [[-0.3377]],
#
#          ...,
#
#          [[ 0.6242]],
#
#          [[ 0.1527]],
#
#          [[ 0.4186]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0734]],
#
#          [[-0.2446]],
#
#          [[-0.0766]],
#
#          ...,
#
#          [[ 0.6265]],
#
#          [[ 0.1553]],
#
#          [[-0.1515]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0785]],
#
#          [[-0.8872]],
#
#          [[-0.2590]],
#
#          ...,
#
#          [[ 0.6460]],
#
#          [[ 0.5261]],
#
#          [[ 0.6556]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0439]],
#
#          [[-1.2134]],
#
#          [[-0.0437]],
#
#          ...,
#
#          [[ 0.5080]],
#
#          [[ 0.6009]],
#
#          [[-0.2349]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0855]],
#
#          [[-1.1946]],
#
#          [[-0.1915]],
#
#          ...,
#
#          [[ 0.4464]],
#
#          [[ 0.5160]],
#
#          [[-0.1061]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4899]],
#
#          [[-1.0206]],
#
#          [[-0.2095]],
#
#          ...,
#
#          [[ 0.2317]],
#
#          [[ 0.6505]],
#
#          [[ 0.4887]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1297]],
#
#          [[-0.9387]],
#
#          [[-0.0437]],
#
#          ...,
#
#          [[ 0.2475]],
#
#          [[ 1.0398]],
#
#          [[ 0.0913]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1297]],
#
#          [[-0.9387]],
#
#          [[-0.0437]],
#
#          ...,
#
#          [[ 0.2475]],
#
#          [[ 1.0398]],
#
#          [[ 0.0913]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3430]],
#
#          [[-0.8015]],
#
#          [[ 0.0094]],
#
#          ...,
#
#          [[ 0.2667]],
#
#          [[ 0.6332]],
#
#          [[ 0.0108]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1297]],
#
#          [[-0.9387]],
#
#          [[-0.0437]],
#
#          ...,
#
#          [[ 0.2475]],
#
#          [[ 1.0398]],
#
#          [[ 0.0913]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1297]],
#
#          [[-0.9387]],
#
#          [[-0.0437]],
#
#          ...,
#
#          [[ 0.2475]],
#
#          [[ 1.0398]],
#
#          [[ 0.0913]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5219]],
#
#          [[ 0.0918]],
#
#          [[-0.0294]],
#
#          ...,
#
#          [[ 0.0029]],
#
#          [[ 0.2895]],
#
#          [[ 0.0146]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5219]],
#
#          [[ 0.0918]],
#
#          [[-0.0294]],
#
#          ...,
#
#          [[ 0.0029]],
#
#          [[ 0.2895]],
#
#          [[ 0.0146]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0441]],
#
#          [[-0.1878]],
#
#          [[-0.4264]],
#
#          ...,
#
#          [[ 0.3336]],
#
#          [[ 0.4529]],
#
#          [[ 0.0825]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5219]],
#
#          [[ 0.0918]],
#
#          [[-0.0294]],
#
#          ...,
#
#          [[ 0.0029]],
#
#          [[ 0.2895]],
#
#          [[ 0.0146]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0441]],
#
#          [[-0.1878]],
#
#          [[-0.4264]],
#
#          ...,
#
#          [[ 0.3336]],
#
#          [[ 0.4529]],
#
#          [[ 0.0825]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5219]],
#
#          [[ 0.0918]],
#
#          [[-0.0294]],
#
#          ...,
#
#          [[ 0.0029]],
#
#          [[ 0.2895]],
#
#          [[ 0.0146]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0441]],
#
#          [[-0.1878]],
#
#          [[-0.4264]],
#
#          ...,
#
#          [[ 0.3336]],
#
#          [[ 0.4529]],
#
#          [[ 0.0825]]]], requires_grad=True)
# loop
# tensor([[[[ 0.6196]],
#
#          [[-1.0807]],
#
#          [[-0.1454]],
#
#          ...,
#
#          [[-0.0575]],
#
#          [[ 0.1416]],
#
#          [[-0.0085]]]], requires_grad=True)
# loop
# tensor([[[[ 0.6196]],
#
#          [[-1.0807]],
#
#          [[-0.1454]],
#
#          ...,
#
#          [[-0.0575]],
#
#          [[ 0.1416]],
#
#          [[-0.0085]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2243]],
#
#          [[-0.7209]],
#
#          [[-0.0833]],
#
#          ...,
#
#          [[ 0.0191]],
#
#          [[ 0.2723]],
#
#          [[ 0.8772]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4694]],
#
#          [[ 0.1258]],
#
#          [[ 0.1468]],
#
#          ...,
#
#          [[-0.0838]],
#
#          [[ 0.2754]],
#
#          [[ 0.1887]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3185]],
#
#          [[-0.6763]],
#
#          [[-0.5716]],
#
#          ...,
#
#          [[ 0.0394]],
#
#          [[ 0.1484]],
#
#          [[-0.2694]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2256]],
#
#          [[-1.2053]],
#
#          [[ 0.0535]],
#
#          ...,
#
#          [[ 0.2317]],
#
#          [[ 0.3892]],
#
#          [[-0.0031]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3185]],
#
#          [[-0.6763]],
#
#          [[-0.5716]],
#
#          ...,
#
#          [[ 0.0394]],
#
#          [[ 0.1484]],
#
#          [[-0.2694]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3185]],
#
#          [[-0.6763]],
#
#          [[-0.5716]],
#
#          ...,
#
#          [[ 0.0394]],
#
#          [[ 0.1484]],
#
#          [[-0.2694]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4590]],
#
#          [[-1.2546]],
#
#          [[-0.7120]],
#
#          ...,
#
#          [[ 0.0803]],
#
#          [[ 0.4002]],
#
#          [[-0.4400]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2262]],
#
#          [[ 0.3477]],
#
#          [[-0.0996]],
#
#          ...,
#
#          [[ 0.6225]],
#
#          [[ 0.0331]],
#
#          [[-0.5094]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0510]],
#
#          [[-0.6679]],
#
#          [[ 0.0747]],
#
#          ...,
#
#          [[ 0.6742]],
#
#          [[ 0.3534]],
#
#          [[ 0.5195]]]], requires_grad=True)
# loop
# tensor([[[[-0.0623]],
#
#          [[-0.4902]],
#
#          [[-0.7051]],
#
#          ...,
#
#          [[ 0.5768]],
#
#          [[ 0.3373]],
#
#          [[-0.6068]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1825]],
#
#          [[-0.2825]],
#
#          [[-0.3856]],
#
#          ...,
#
#          [[ 0.7934]],
#
#          [[ 0.1818]],
#
#          [[-0.4214]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0610]],
#
#          [[-0.6869]],
#
#          [[-0.2965]],
#
#          ...,
#
#          [[ 0.5851]],
#
#          [[ 0.1907]],
#
#          [[-0.8352]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1834]],
#
#          [[-0.5928]],
#
#          [[-0.0105]],
#
#          ...,
#
#          [[ 0.4855]],
#
#          [[ 0.0776]],
#
#          [[-0.8288]]]], requires_grad=True)
# loop
# tensor([[[[-0.0623]],
#
#          [[-0.4902]],
#
#          [[-0.7051]],
#
#          ...,
#
#          [[ 0.5768]],
#
#          [[ 0.3373]],
#
#          [[-0.6068]]]], requires_grad=True)
# loop
# tensor([[[[-0.0623]],
#
#          [[-0.4902]],
#
#          [[-0.7051]],
#
#          ...,
#
#          [[ 0.5768]],
#
#          [[ 0.3373]],
#
#          [[-0.6068]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[-0.2016]],
#
#          [[-0.8367]],
#
#          [[-0.0675]],
#
#          ...,
#
#          [[ 0.2609]],
#
#          [[ 0.4752]],
#
#          [[-0.5280]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1783]],
#
#          [[-0.4344]],
#
#          [[-0.3982]],
#
#          ...,
#
#          [[ 0.3992]],
#
#          [[ 0.3366]],
#
#          [[-0.9895]]]], requires_grad=True)
# loop
# tensor([[[[-0.3272]],
#
#          [[-0.2195]],
#
#          [[-0.4269]],
#
#          ...,
#
#          [[ 0.4398]],
#
#          [[ 0.4169]],
#
#          [[-0.3818]]]], requires_grad=True)
# loop
# tensor([[[[-0.2799]],
#
#          [[-0.2137]],
#
#          [[-0.0070]],
#
#          ...,
#
#          [[ 0.3847]],
#
#          [[ 0.2111]],
#
#          [[-0.8416]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1783]],
#
#          [[-0.4344]],
#
#          [[-0.3982]],
#
#          ...,
#
#          [[ 0.3992]],
#
#          [[ 0.3366]],
#
#          [[-0.9895]]]], requires_grad=True)
# loop
# tensor([[[[-0.3272]],
#
#          [[-0.2195]],
#
#          [[-0.4269]],
#
#          ...,
#
#          [[ 0.4398]],
#
#          [[ 0.4169]],
#
#          [[-0.3818]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1825]],
#
#          [[-0.2825]],
#
#          [[-0.3856]],
#
#          ...,
#
#          [[ 0.7934]],
#
#          [[ 0.1818]],
#
#          [[-0.4214]]]], requires_grad=True)
# loop
# tensor([[[[-0.2016]],
#
#          [[-0.8367]],
#
#          [[-0.0675]],
#
#          ...,
#
#          [[ 0.2609]],
#
#          [[ 0.4752]],
#
#          [[-0.5280]]]], requires_grad=True)
# loop
# tensor([[[[-0.0288]],
#
#          [[-0.9730]],
#
#          [[-0.1777]],
#
#          ...,
#
#          [[ 0.2123]],
#
#          [[ 0.4177]],
#
#          [[-0.6337]]]], requires_grad=True)
# loop
# tensor([[[[-0.4693]],
#
#          [[-0.7841]],
#
#          [[-0.3888]],
#
#          ...,
#
#          [[ 0.0112]],
#
#          [[ 0.2388]],
#
#          [[-0.2689]]]], requires_grad=True)
# loop
# tensor([[[[-0.1257]],
#
#          [[-0.6566]],
#
#          [[-0.1506]],
#
#          ...,
#
#          [[ 0.4565]],
#
#          [[ 0.4061]],
#
#          [[-0.3228]]]], requires_grad=True)
# loop
# tensor([[[[-0.2743]],
#
#          [[-0.6960]],
#
#          [[-0.1339]],
#
#          ...,
#
#          [[ 0.0330]],
#
#          [[ 0.5871]],
#
#          [[ 0.2065]]]], requires_grad=True)
# loop
# tensor([[[[-0.1257]],
#
#          [[-0.6566]],
#
#          [[-0.1506]],
#
#          ...,
#
#          [[ 0.4565]],
#
#          [[ 0.4061]],
#
#          [[-0.3228]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1253]],
#
#          [[-1.2719]],
#
#          [[-0.1515]],
#
#          ...,
#
#          [[ 0.1208]],
#
#          [[ 0.2672]],
#
#          [[ 0.1677]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5050]],
#
#          [[-0.8000]],
#
#          [[ 0.2760]],
#
#          ...,
#
#          [[ 0.2233]],
#
#          [[ 0.2724]],
#
#          [[-0.3333]]]], requires_grad=True)
# loop
# tensor([[[[-0.1401]],
#
#          [[-0.8357]],
#
#          [[-0.9198]],
#
#          ...,
#
#          [[ 0.2022]],
#
#          [[ 0.1083]],
#
#          [[-0.4925]]]], requires_grad=True)
# loop
# tensor([[[[-0.1129]],
#
#          [[-0.5236]],
#
#          [[-0.8663]],
#
#          ...,
#
#          [[ 0.1186]],
#
#          [[ 0.1940]],
#
#          [[-0.3815]]]], requires_grad=True)
# loop
# tensor([[[[-0.4059]],
#
#          [[-0.8717]],
#
#          [[-0.6281]],
#
#          ...,
#
#          [[ 0.1149]],
#
#          [[ 0.4128]],
#
#          [[-0.5206]]]], requires_grad=True)
# loop
# tensor([[[[-0.0378]],
#
#          [[-0.6284]],
#
#          [[ 0.2776]],
#
#          ...,
#
#          [[ 0.1895]],
#
#          [[ 0.1557]],
#
#          [[-0.1318]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2034]],
#
#          [[ 0.4974]],
#
#          [[ 0.8241]],
#
#          ...,
#
#          [[ 0.1435]],
#
#          [[ 0.0412]],
#
#          [[-0.1814]]]], requires_grad=True)
# loop
# tensor([[[[0.1344]],
#
#          [[0.1870]],
#
#          [[0.4152]],
#
#          ...,
#
#          [[0.3735]],
#
#          [[0.2015]],
#
#          [[0.0396]]]], requires_grad=True)
# loop
# tensor([[[[-0.1461]],
#
#          [[ 0.2034]],
#
#          [[ 0.4720]],
#
#          ...,
#
#          [[ 0.1445]],
#
#          [[ 0.2310]],
#
#          [[-0.0979]]]], requires_grad=True)
# loop
# tensor([[[[0.2601]],
#
#          [[0.5396]],
#
#          [[0.3718]],
#
#          ...,
#
#          [[0.0949]],
#
#          [[0.5478]],
#
#          [[0.0876]]]], requires_grad=True)
# loop
# tensor([[[[0.1367]],
#
#          [[0.5707]],
#
#          [[0.4239]],
#
#          ...,
#
#          [[0.1715]],
#
#          [[0.2882]],
#
#          [[0.5049]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1900]],
#
#          [[-0.0920]],
#
#          [[ 0.6300]],
#
#          ...,
#
#          [[ 0.2659]],
#
#          [[ 0.2695]],
#
#          [[ 0.3472]]]], requires_grad=True)
# loop
# tensor([[[[0.2556]],
#
#          [[0.4032]],
#
#          [[0.8630]],
#
#          ...,
#
#          [[0.2520]],
#
#          [[0.3971]],
#
#          [[0.3561]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0856]],
#
#          [[-0.0344]],
#
#          [[ 0.8403]],
#
#          ...,
#
#          [[ 0.1872]],
#
#          [[ 0.3049]],
#
#          [[ 0.3771]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1345]],
#
#          [[-0.0719]],
#
#          [[ 0.6828]],
#
#          ...,
#
#          [[ 0.0389]],
#
#          [[ 0.3391]],
#
#          [[-0.0309]]]], requires_grad=True)
# loop
# tensor([[[[-0.0799]],
#
#          [[-0.0381]],
#
#          [[ 0.3605]],
#
#          ...,
#
#          [[ 0.1128]],
#
#          [[ 0.2468]],
#
#          [[ 0.5452]]]], requires_grad=True)
# loop
# tensor([[[[-0.0526]],
#
#          [[ 0.3398]],
#
#          [[ 0.7224]],
#
#          ...,
#
#          [[ 0.2713]],
#
#          [[ 0.0827]],
#
#          [[ 0.4567]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[0.2556]],
#
#          [[0.4032]],
#
#          [[0.8630]],
#
#          ...,
#
#          [[0.2520]],
#
#          [[0.3971]],
#
#          [[0.3561]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1094]],
#
#          [[ 0.3922]],
#
#          [[ 0.4236]],
#
#          ...,
#
#          [[ 0.2213]],
#
#          [[ 0.5482]],
#
#          [[-0.5358]]]], requires_grad=True)
# loop
# tensor([[[[-0.0610]],
#
#          [[ 0.1770]],
#
#          [[ 0.7827]],
#
#          ...,
#
#          [[ 0.1821]],
#
#          [[ 0.3629]],
#
#          [[-0.0836]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[-0.0799]],
#
#          [[-0.0381]],
#
#          [[ 0.3605]],
#
#          ...,
#
#          [[ 0.1128]],
#
#          [[ 0.2468]],
#
#          [[ 0.5452]]]], requires_grad=True)
# loop
# tensor([[[[-0.0526]],
#
#          [[ 0.3398]],
#
#          [[ 0.7224]],
#
#          ...,
#
#          [[ 0.2713]],
#
#          [[ 0.0827]],
#
#          [[ 0.4567]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1345]],
#
#          [[-0.0719]],
#
#          [[ 0.6828]],
#
#          ...,
#
#          [[ 0.0389]],
#
#          [[ 0.3391]],
#
#          [[-0.0309]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0618]],
#
#          [[ 0.6918]],
#
#          [[-0.1806]],
#
#          ...,
#
#          [[ 0.1919]],
#
#          [[ 0.2603]],
#
#          [[ 0.2597]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0900]],
#
#          [[-0.0672]],
#
#          [[-0.0737]],
#
#          ...,
#
#          [[-0.0251]],
#
#          [[ 0.3466]],
#
#          [[ 0.2895]]]], requires_grad=True)
# loop
# tensor([[[[0.1344]],
#
#          [[0.1870]],
#
#          [[0.4152]],
#
#          ...,
#
#          [[0.3735]],
#
#          [[0.2015]],
#
#          [[0.0396]]]], requires_grad=True)
# loop
# tensor([[[[-0.1461]],
#
#          [[ 0.2034]],
#
#          [[ 0.4720]],
#
#          ...,
#
#          [[ 0.1445]],
#
#          [[ 0.2310]],
#
#          [[-0.0979]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0524]],
#
#          [[-0.6663]],
#
#          [[ 0.1337]],
#
#          ...,
#
#          [[ 0.4817]],
#
#          [[ 0.2663]],
#
#          [[-0.1837]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0283]],
#
#          [[-0.0494]],
#
#          [[ 0.4712]],
#
#          ...,
#
#          [[-0.0345]],
#
#          [[ 0.2743]],
#
#          [[ 0.0625]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1745]],
#
#          [[-0.0783]],
#
#          [[ 0.8514]],
#
#          ...,
#
#          [[ 0.0875]],
#
#          [[ 0.4607]],
#
#          [[ 0.8203]]]], requires_grad=True)
# loop
# tensor([[[[-0.0642]],
#
#          [[-0.7398]],
#
#          [[ 0.8775]],
#
#          ...,
#
#          [[ 0.0936]],
#
#          [[ 0.3821]],
#
#          [[ 0.4691]]]], requires_grad=True)
# loop
# tensor([[[[0.2393]],
#
#          [[0.1637]],
#
#          [[0.8467]],
#
#          ...,
#
#          [[0.0994]],
#
#          [[0.3492]],
#
#          [[0.3499]]]], requires_grad=True)
# loop
# tensor([[[[0.2485]],
#
#          [[0.1581]],
#
#          [[0.6421]],
#
#          ...,
#
#          [[0.2056]],
#
#          [[0.5993]],
#
#          [[0.1898]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2596]],
#
#          [[-0.0921]],
#
#          [[ 0.4141]],
#
#          ...,
#
#          [[ 0.1988]],
#
#          [[ 0.4582]],
#
#          [[ 0.0919]]]], requires_grad=True)
# loop
# tensor([[[[-0.2487]],
#
#          [[-0.0429]],
#
#          [[ 0.4618]],
#
#          ...,
#
#          [[ 0.2404]],
#
#          [[ 0.3771]],
#
#          [[ 0.3507]]]], requires_grad=True)
# loop
# tensor([[[[-0.0642]],
#
#          [[-0.7398]],
#
#          [[ 0.8775]],
#
#          ...,
#
#          [[ 0.0936]],
#
#          [[ 0.3821]],
#
#          [[ 0.4691]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1639]],
#
#          [[ 0.0277]],
#
#          [[-0.1905]],
#
#          ...,
#
#          [[ 0.3065]],
#
#          [[ 0.1088]],
#
#          [[ 0.0738]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2932]],
#
#          [[ 0.0263]],
#
#          [[-0.1170]],
#
#          ...,
#
#          [[-0.1009]],
#
#          [[ 0.0518]],
#
#          [[ 0.5229]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4033]],
#
#          [[-0.1678]],
#
#          [[ 0.3662]],
#
#          ...,
#
#          [[-0.0339]],
#
#          [[ 0.1696]],
#
#          [[ 0.4510]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3796]],
#
#          [[-0.0911]],
#
#          [[ 0.6842]],
#
#          ...,
#
#          [[ 0.2559]],
#
#          [[ 0.2866]],
#
#          [[-0.0747]]]], requires_grad=True)
# loop
# tensor([[[[-0.2406]],
#
#          [[-0.4509]],
#
#          [[-0.2495]],
#
#          ...,
#
#          [[ 0.0759]],
#
#          [[ 0.3123]],
#
#          [[ 0.3686]]]], requires_grad=True)
# loop
# tensor([[[[-0.0077]],
#
#          [[ 0.1083]],
#
#          [[ 0.2655]],
#
#          ...,
#
#          [[-0.0922]],
#
#          [[ 0.0914]],
#
#          [[-0.3713]]]], requires_grad=True)
# loop
# tensor([[[[-0.1187]],
#
#          [[-0.0777]],
#
#          [[ 0.5467]],
#
#          ...,
#
#          [[ 0.0838]],
#
#          [[ 0.0651]],
#
#          [[ 0.4318]]]], requires_grad=True)
# loop
# tensor([[[[ 0.6536]],
#
#          [[-0.1770]],
#
#          [[ 0.6292]],
#
#          ...,
#
#          [[ 0.0758]],
#
#          [[ 0.1001]],
#
#          [[ 0.4018]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4476]],
#
#          [[-0.3992]],
#
#          [[ 0.4841]],
#
#          ...,
#
#          [[-0.0032]],
#
#          [[-0.0088]],
#
#          [[ 0.1931]]]], requires_grad=True)
# loop
# tensor([[[[-0.0865]],
#
#          [[-0.3876]],
#
#          [[ 0.5072]],
#
#          ...,
#
#          [[ 0.0567]],
#
#          [[ 0.1512]],
#
#          [[-0.0647]]]], requires_grad=True)
# loop
# tensor([[[[-0.1187]],
#
#          [[-0.0777]],
#
#          [[ 0.5467]],
#
#          ...,
#
#          [[ 0.0838]],
#
#          [[ 0.0651]],
#
#          [[ 0.4318]]]], requires_grad=True)
# loop
# tensor([[[[-0.1172]],
#
#          [[-0.0694]],
#
#          [[ 0.8312]],
#
#          ...,
#
#          [[-0.2199]],
#
#          [[ 0.2675]],
#
#          [[-0.3320]]]], requires_grad=True)
# loop
# tensor([[[[-0.1172]],
#
#          [[-0.0694]],
#
#          [[ 0.8312]],
#
#          ...,
#
#          [[-0.2199]],
#
#          [[ 0.2675]],
#
#          [[-0.3320]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0436]],
#
#          [[-0.0646]],
#
#          [[ 0.8788]],
#
#          ...,
#
#          [[-0.1858]],
#
#          [[ 0.2134]],
#
#          [[ 0.0874]]]], requires_grad=True)
# loop
# tensor([[[[-0.3960]],
#
#          [[-0.1360]],
#
#          [[ 1.1607]],
#
#          ...,
#
#          [[ 0.0537]],
#
#          [[ 0.5011]],
#
#          [[ 0.2213]]]], requires_grad=True)
# loop
# tensor([[[[-0.0653]],
#
#          [[-0.3320]],
#
#          [[ 0.7170]],
#
#          ...,
#
#          [[-0.0919]],
#
#          [[ 0.1719]],
#
#          [[-0.5240]]]], requires_grad=True)
# loop
# tensor([[[[0.4099]],
#
#          [[0.2379]],
#
#          [[0.1313]],
#
#          ...,
#
#          [[0.0873]],
#
#          [[0.2974]],
#
#          [[0.1016]]]], requires_grad=True)
# loop
# tensor([[[[0.2705]],
#
#          [[0.1863]],
#
#          [[0.1767]],
#
#          ...,
#
#          [[0.5050]],
#
#          [[0.2230]],
#
#          [[0.4829]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3098]],
#
#          [[-0.1459]],
#
#          [[ 0.1832]],
#
#          ...,
#
#          [[ 0.5743]],
#
#          [[ 0.5728]],
#
#          [[ 0.1645]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1763]],
#
#          [[-0.3502]],
#
#          [[ 0.2393]],
#
#          ...,
#
#          [[ 0.3988]],
#
#          [[ 0.2316]],
#
#          [[ 0.1487]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1012]],
#
#          [[-0.1423]],
#
#          [[-0.0047]],
#
#          ...,
#
#          [[ 0.4331]],
#
#          [[ 0.3934]],
#
#          [[ 0.6017]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[0.1597]],
#
#          [[0.0694]],
#
#          [[0.1600]],
#
#          ...,
#
#          [[0.4218]],
#
#          [[0.2316]],
#
#          [[0.3568]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1012]],
#
#          [[-0.1423]],
#
#          [[-0.0047]],
#
#          ...,
#
#          [[ 0.4331]],
#
#          [[ 0.3934]],
#
#          [[ 0.6017]]]], requires_grad=True)
# loop
# tensor([[[[-0.0217]],
#
#          [[-0.6282]],
#
#          [[ 0.1574]],
#
#          ...,
#
#          [[ 0.5377]],
#
#          [[ 0.2369]],
#
#          [[ 0.0422]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2849]],
#
#          [[-0.0133]],
#
#          [[ 0.3629]],
#
#          ...,
#
#          [[ 0.6618]],
#
#          [[ 0.3549]],
#
#          [[-0.3479]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1345]],
#
#          [[-0.0719]],
#
#          [[ 0.6828]],
#
#          ...,
#
#          [[ 0.0389]],
#
#          [[ 0.3391]],
#
#          [[-0.0309]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3200]],
#
#          [[-0.1261]],
#
#          [[ 0.3768]],
#
#          ...,
#
#          [[ 0.5293]],
#
#          [[ 0.5237]],
#
#          [[-0.2248]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1842]],
#
#          [[-0.4866]],
#
#          [[ 0.6037]],
#
#          ...,
#
#          [[ 0.4910]],
#
#          [[ 0.4852]],
#
#          [[ 0.4623]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3115]],
#
#          [[-0.1200]],
#
#          [[ 0.4874]],
#
#          ...,
#
#          [[ 0.3698]],
#
#          [[ 0.1646]],
#
#          [[-0.2261]]]], requires_grad=True)
# loop
# tensor([[[[0.2890]],
#
#          [[0.3059]],
#
#          [[0.7085]],
#
#          ...,
#
#          [[0.4952]],
#
#          [[0.0527]],
#
#          [[0.0285]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3889]],
#
#          [[-0.0099]],
#
#          [[ 0.3804]],
#
#          ...,
#
#          [[ 0.4279]],
#
#          [[ 0.0827]],
#
#          [[-0.1381]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3115]],
#
#          [[-0.1200]],
#
#          [[ 0.4874]],
#
#          ...,
#
#          [[ 0.3698]],
#
#          [[ 0.1646]],
#
#          [[-0.2261]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1938]],
#
#          [[ 0.5178]],
#
#          [[ 0.3090]],
#
#          ...,
#
#          [[ 0.5446]],
#
#          [[ 0.0856]],
#
#          [[-0.1071]]]], requires_grad=True)
# loop
# tensor([[[[0.2890]],
#
#          [[0.3059]],
#
#          [[0.7085]],
#
#          ...,
#
#          [[0.4952]],
#
#          [[0.0527]],
#
#          [[0.0285]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1572]],
#
#          [[-0.1983]],
#
#          [[ 0.8223]],
#
#          ...,
#
#          [[ 0.3605]],
#
#          [[ 0.1282]],
#
#          [[ 0.2851]]]], requires_grad=True)
# loop
# tensor([[[[-0.0232]],
#
#          [[-0.0666]],
#
#          [[ 0.8260]],
#
#          ...,
#
#          [[ 0.3066]],
#
#          [[ 0.3107]],
#
#          [[ 0.4852]]]], requires_grad=True)
# loop
# tensor([[[[0.2890]],
#
#          [[0.3059]],
#
#          [[0.7085]],
#
#          ...,
#
#          [[0.4952]],
#
#          [[0.0527]],
#
#          [[0.0285]]]], requires_grad=True)
# loop
# tensor([[[[0.3943]],
#
#          [[0.2117]],
#
#          [[0.5474]],
#
#          ...,
#
#          [[0.4509]],
#
#          [[0.2011]],
#
#          [[0.4648]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4184]],
#
#          [[-0.3568]],
#
#          [[ 0.2106]],
#
#          ...,
#
#          [[ 0.4576]],
#
#          [[ 0.1987]],
#
#          [[ 0.2527]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2016]],
#
#          [[-0.4844]],
#
#          [[ 0.1604]],
#
#          ...,
#
#          [[ 0.3237]],
#
#          [[ 0.3725]],
#
#          [[ 0.4221]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5443]],
#
#          [[-0.5228]],
#
#          [[ 0.3469]],
#
#          ...,
#
#          [[ 0.3863]],
#
#          [[ 0.1888]],
#
#          [[ 1.2502]]]], requires_grad=True)
# loop
# tensor([[[[-0.0232]],
#
#          [[-0.0666]],
#
#          [[ 0.8260]],
#
#          ...,
#
#          [[ 0.3066]],
#
#          [[ 0.3107]],
#
#          [[ 0.4852]]]], requires_grad=True)
# loop
# tensor([[[[-0.0661]],
#
#          [[-0.3989]],
#
#          [[ 0.3313]],
#
#          ...,
#
#          [[ 0.2083]],
#
#          [[ 0.0363]],
#
#          [[-0.3560]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2787]],
#
#          [[-0.1913]],
#
#          [[ 0.0874]],
#
#          ...,
#
#          [[ 0.3640]],
#
#          [[ 0.1053]],
#
#          [[-0.2403]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0857]],
#
#          [[-0.1384]],
#
#          [[ 0.9517]],
#
#          ...,
#
#          [[ 0.3935]],
#
#          [[ 0.1814]],
#
#          [[-0.4204]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1163]],
#
#          [[-0.1851]],
#
#          [[ 1.0247]],
#
#          ...,
#
#          [[ 0.4131]],
#
#          [[ 0.1018]],
#
#          [[-0.3691]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1521]],
#
#          [[-0.5229]],
#
#          [[ 0.5844]],
#
#          ...,
#
#          [[ 0.4534]],
#
#          [[ 0.0519]],
#
#          [[-0.2977]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1697]],
#
#          [[-0.3935]],
#
#          [[ 0.8195]],
#
#          ...,
#
#          [[ 0.3443]],
#
#          [[ 0.0869]],
#
#          [[-0.0465]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3855]],
#
#          [[-0.1127]],
#
#          [[ 0.5073]],
#
#          ...,
#
#          [[ 0.3005]],
#
#          [[ 0.1568]],
#
#          [[-0.5030]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0854]],
#
#          [[-0.0612]],
#
#          [[ 0.4076]],
#
#          ...,
#
#          [[ 0.0852]],
#
#          [[ 0.2891]],
#
#          [[ 0.2614]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0784]],
#
#          [[ 0.1550]],
#
#          [[ 0.4503]],
#
#          ...,
#
#          [[ 0.1475]],
#
#          [[ 0.4719]],
#
#          [[-0.3710]]]], requires_grad=True)
# loop
# tensor([[[[-0.2868]],
#
#          [[-0.1371]],
#
#          [[ 0.3406]],
#
#          ...,
#
#          [[ 0.2186]],
#
#          [[ 0.4459]],
#
#          [[-0.4557]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2051]],
#
#          [[-0.3076]],
#
#          [[-0.0308]],
#
#          ...,
#
#          [[ 0.0243]],
#
#          [[ 0.1697]],
#
#          [[ 0.1552]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1354]],
#
#          [[-0.3480]],
#
#          [[ 0.7065]],
#
#          ...,
#
#          [[ 0.4916]],
#
#          [[ 0.3937]],
#
#          [[-0.1278]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1403]],
#
#          [[-0.4584]],
#
#          [[-0.0536]],
#
#          ...,
#
#          [[-0.0445]],
#
#          [[ 0.1340]],
#
#          [[ 0.2467]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2034]],
#
#          [[-0.3261]],
#
#          [[ 0.0793]],
#
#          ...,
#
#          [[ 0.3005]],
#
#          [[ 0.2740]],
#
#          [[ 0.4718]]]], requires_grad=True)
# loop
# tensor([[[[-0.0203]],
#
#          [[-0.5607]],
#
#          [[ 0.5048]],
#
#          ...,
#
#          [[ 0.1690]],
#
#          [[ 0.5103]],
#
#          [[ 0.5510]]]], requires_grad=True)
# loop
# tensor([[[[-0.0011]],
#
#          [[-0.1405]],
#
#          [[ 0.3333]],
#
#          ...,
#
#          [[ 0.5044]],
#
#          [[ 0.5042]],
#
#          [[ 0.6042]]]], requires_grad=True)
# loop
# tensor([[[[-0.1040]],
#
#          [[-0.2902]],
#
#          [[ 0.6740]],
#
#          ...,
#
#          [[ 0.0301]],
#
#          [[ 0.2331]],
#
#          [[ 0.0282]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0851]],
#
#          [[-0.5660]],
#
#          [[ 0.8581]],
#
#          ...,
#
#          [[ 0.2897]],
#
#          [[ 0.1404]],
#
#          [[-0.4025]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0240]],
#
#          [[-0.4333]],
#
#          [[ 0.5818]],
#
#          ...,
#
#          [[ 0.5781]],
#
#          [[ 0.3458]],
#
#          [[-0.3306]]]], requires_grad=True)
# loop
# tensor([[[[-0.1968]],
#
#          [[-0.3948]],
#
#          [[ 0.6105]],
#
#          ...,
#
#          [[ 0.5034]],
#
#          [[ 0.0903]],
#
#          [[ 0.0237]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3724]],
#
#          [[-0.7012]],
#
#          [[ 0.5784]],
#
#          ...,
#
#          [[ 0.4436]],
#
#          [[ 0.3344]],
#
#          [[-0.5794]]]], requires_grad=True)
# loop
# tensor([[[[-0.3691]],
#
#          [[-0.4799]],
#
#          [[ 0.7407]],
#
#          ...,
#
#          [[-0.1311]],
#
#          [[ 0.3603]],
#
#          [[-0.0016]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3724]],
#
#          [[-0.7012]],
#
#          [[ 0.5784]],
#
#          ...,
#
#          [[ 0.4436]],
#
#          [[ 0.3344]],
#
#          [[-0.5794]]]], requires_grad=True)
# loop
# tensor([[[[-0.5114]],
#
#          [[-0.3842]],
#
#          [[-0.7634]],
#
#          ...,
#
#          [[ 0.3454]],
#
#          [[ 0.2303]],
#
#          [[ 0.7040]]]], requires_grad=True)
# loop
# tensor([[[[-0.7562]],
#
#          [[ 0.0034]],
#
#          [[ 0.4800]],
#
#          ...,
#
#          [[ 0.2995]],
#
#          [[ 0.4496]],
#
#          [[ 0.7003]]]], requires_grad=True)
# loop
# tensor([[[[-0.4953]],
#
#          [[-0.0085]],
#
#          [[ 0.5762]],
#
#          ...,
#
#          [[ 0.2112]],
#
#          [[ 0.4061]],
#
#          [[ 0.7544]]]], requires_grad=True)
# loop
# tensor([[[[-0.6896]],
#
#          [[-0.1876]],
#
#          [[ 0.7867]],
#
#          ...,
#
#          [[ 0.1314]],
#
#          [[ 0.1682]],
#
#          [[ 0.4476]]]], requires_grad=True)
# loop
# tensor([[[[-0.2060]],
#
#          [[-0.3528]],
#
#          [[ 0.7090]],
#
#          ...,
#
#          [[ 0.1976]],
#
#          [[ 0.2251]],
#
#          [[-0.0573]]]], requires_grad=True)
# loop
# tensor([[[[-0.2060]],
#
#          [[-0.3528]],
#
#          [[ 0.7090]],
#
#          ...,
#
#          [[ 0.1976]],
#
#          [[ 0.2251]],
#
#          [[-0.0573]]]], requires_grad=True)
# loop
# tensor([[[[-0.6167]],
#
#          [[-0.1041]],
#
#          [[ 0.9245]],
#
#          ...,
#
#          [[ 0.3639]],
#
#          [[ 0.2534]],
#
#          [[ 0.1621]]]], requires_grad=True)
# loop
# tensor([[[[-0.1530]],
#
#          [[-0.2717]],
#
#          [[ 0.6542]],
#
#          ...,
#
#          [[ 0.0998]],
#
#          [[ 0.1837]],
#
#          [[-0.1474]]]], requires_grad=True)
# loop
# tensor([[[[-0.2060]],
#
#          [[-0.3528]],
#
#          [[ 0.7090]],
#
#          ...,
#
#          [[ 0.1976]],
#
#          [[ 0.2251]],
#
#          [[-0.0573]]]], requires_grad=True)
# loop
# tensor([[[[-0.0245]],
#
#          [[-0.6035]],
#
#          [[ 0.4854]],
#
#          ...,
#
#          [[ 0.1726]],
#
#          [[ 0.2247]],
#
#          [[ 0.3606]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2220]],
#
#          [[-0.2020]],
#
#          [[ 1.1905]],
#
#          ...,
#
#          [[ 0.0301]],
#
#          [[ 0.3590]],
#
#          [[ 1.3755]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1304]],
#
#          [[-0.1035]],
#
#          [[ 0.8505]],
#
#          ...,
#
#          [[ 0.3563]],
#
#          [[ 0.0491]],
#
#          [[ 0.1709]]]], requires_grad=True)
# loop
# tensor([[[[-0.1860]],
#
#          [[-0.0642]],
#
#          [[ 0.9483]],
#
#          ...,
#
#          [[ 0.1782]],
#
#          [[-0.2024]],
#
#          [[-0.1890]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1621]],
#
#          [[-0.1091]],
#
#          [[ 1.0951]],
#
#          ...,
#
#          [[ 0.2074]],
#
#          [[-0.2686]],
#
#          [[ 0.3762]]]], requires_grad=True)
# loop
# tensor([[[[-0.0394]],
#
#          [[ 0.1959]],
#
#          [[ 1.1515]],
#
#          ...,
#
#          [[ 0.2928]],
#
#          [[-0.1285]],
#
#          [[ 0.4004]]]], requires_grad=True)
# loop
# tensor([[[[-0.1860]],
#
#          [[-0.0642]],
#
#          [[ 0.9483]],
#
#          ...,
#
#          [[ 0.1782]],
#
#          [[-0.2024]],
#
#          [[-0.1890]]]], requires_grad=True)
# loop
# tensor([[[[-0.0822]],
#
#          [[-0.0176]],
#
#          [[ 0.9482]],
#
#          ...,
#
#          [[ 0.4598]],
#
#          [[-0.0453]],
#
#          [[ 0.3139]]]], requires_grad=True)
# loop
# tensor([[[[-0.0687]],
#
#          [[ 0.7286]],
#
#          [[-0.2831]],
#
#          ...,
#
#          [[ 0.2263]],
#
#          [[ 0.3060]],
#
#          [[ 0.2489]]]], requires_grad=True)
# loop
# tensor([[[[-0.0277]],
#
#          [[ 0.2266]],
#
#          [[ 1.2523]],
#
#          ...,
#
#          [[ 0.4021]],
#
#          [[ 0.5006]],
#
#          [[ 0.3220]]]], requires_grad=True)
# loop
# tensor([[[[-0.3319]],
#
#          [[-0.2147]],
#
#          [[ 0.1909]],
#
#          ...,
#
#          [[ 0.3031]],
#
#          [[ 0.4208]],
#
#          [[-0.1368]]]], requires_grad=True)
# loop
# tensor([[[[-0.0911]],
#
#          [[ 0.2607]],
#
#          [[ 1.2924]],
#
#          ...,
#
#          [[ 0.0759]],
#
#          [[ 0.0098]],
#
#          [[-0.0121]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0686]],
#
#          [[-0.3185]],
#
#          [[ 0.1810]],
#
#          ...,
#
#          [[ 0.1952]],
#
#          [[ 0.3556]],
#
#          [[-0.9523]]]], requires_grad=True)
# loop
# tensor([[[[-0.0249]],
#
#          [[-0.1434]],
#
#          [[ 0.4823]],
#
#          ...,
#
#          [[ 0.1248]],
#
#          [[ 0.1610]],
#
#          [[-0.1759]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0677]],
#
#          [[-0.4314]],
#
#          [[ 0.8447]],
#
#          ...,
#
#          [[-0.1396]],
#
#          [[ 0.2162]],
#
#          [[-0.2562]]]], requires_grad=True)
# loop
# tensor([[[[-0.2129]],
#
#          [[ 0.0679]],
#
#          [[ 0.1990]],
#
#          ...,
#
#          [[ 0.4592]],
#
#          [[ 0.1167]],
#
#          [[-0.1620]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0917]],
#
#          [[ 0.0097]],
#
#          [[ 0.7427]],
#
#          ...,
#
#          [[-0.2147]],
#
#          [[ 0.0941]],
#
#          [[-0.7452]]]], requires_grad=True)
# loop
# tensor([[[[-0.0249]],
#
#          [[-0.1434]],
#
#          [[ 0.4823]],
#
#          ...,
#
#          [[ 0.1248]],
#
#          [[ 0.1610]],
#
#          [[-0.1759]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0924]],
#
#          [[-0.1889]],
#
#          [[ 0.6629]],
#
#          ...,
#
#          [[ 0.3390]],
#
#          [[ 0.2190]],
#
#          [[-0.6067]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0169]],
#
#          [[-0.1725]],
#
#          [[ 0.4055]],
#
#          ...,
#
#          [[ 0.3938]],
#
#          [[ 0.0914]],
#
#          [[-0.8159]]]], requires_grad=True)
# loop
# tensor([[[[-0.4204]],
#
#          [[ 0.0151]],
#
#          [[-0.4573]],
#
#          ...,
#
#          [[ 0.2097]],
#
#          [[ 0.1289]],
#
#          [[-0.3060]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1105]],
#
#          [[ 0.1442]],
#
#          [[ 0.4090]],
#
#          ...,
#
#          [[ 0.1488]],
#
#          [[ 0.1653]],
#
#          [[-0.2054]]]], requires_grad=True)
# loop
# tensor([[[[-0.0581]],
#
#          [[-0.1099]],
#
#          [[ 0.7455]],
#
#          ...,
#
#          [[ 0.2386]],
#
#          [[ 0.2162]],
#
#          [[-0.5903]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0025]],
#
#          [[-0.1990]],
#
#          [[ 0.6037]],
#
#          ...,
#
#          [[ 0.1078]],
#
#          [[ 0.2107]],
#
#          [[-0.6970]]]], requires_grad=True)
# loop
# tensor([[[[-0.4814]],
#
#          [[-0.1379]],
#
#          [[ 1.2508]],
#
#          ...,
#
#          [[ 0.0807]],
#
#          [[ 0.2554]],
#
#          [[ 0.3636]]]], requires_grad=True)
# loop
# tensor([[[[-0.1581]],
#
#          [[ 0.1510]],
#
#          [[ 1.3840]],
#
#          ...,
#
#          [[ 0.1812]],
#
#          [[ 0.1661]],
#
#          [[ 0.3777]]]], requires_grad=True)
# loop
# tensor([[[[-0.4814]],
#
#          [[-0.1379]],
#
#          [[ 1.2508]],
#
#          ...,
#
#          [[ 0.0807]],
#
#          [[ 0.2554]],
#
#          [[ 0.3636]]]], requires_grad=True)
# loop
# tensor([[[[-0.4814]],
#
#          [[-0.1379]],
#
#          [[ 1.2508]],
#
#          ...,
#
#          [[ 0.0807]],
#
#          [[ 0.2554]],
#
#          [[ 0.3636]]]], requires_grad=True)
# loop
# tensor([[[[ 2.3882e-04]],
#
#          [[-5.6178e-02]],
#
#          [[ 7.3306e-01]],
#
#          ...,
#
#          [[ 8.1556e-02]],
#
#          [[ 3.2699e-01]],
#
#          [[-2.8485e-01]]]], requires_grad=True)
# loop
# tensor([[[[-0.2134]],
#
#          [[-0.7384]],
#
#          [[ 0.6826]],
#
#          ...,
#
#          [[ 0.1742]],
#
#          [[ 0.1281]],
#
#          [[-0.8979]]]], requires_grad=True)
# loop
# tensor([[[[-0.1252]],
#
#          [[-0.8685]],
#
#          [[-0.0856]],
#
#          ...,
#
#          [[ 0.1130]],
#
#          [[ 0.1404]],
#
#          [[-0.1947]]]], requires_grad=True)
# loop
# tensor([[[[-0.3027]],
#
#          [[-0.0140]],
#
#          [[ 0.3875]],
#
#          ...,
#
#          [[-0.0411]],
#
#          [[ 0.1179]],
#
#          [[-0.0389]]]], requires_grad=True)
# loop
# tensor([[[[-0.1244]],
#
#          [[ 0.0073]],
#
#          [[ 0.7708]],
#
#          ...,
#
#          [[-0.1474]],
#
#          [[-0.2723]],
#
#          [[-0.8158]]]], requires_grad=True)
# loop
# tensor([[[[-0.0202]],
#
#          [[ 0.0789]],
#
#          [[ 1.3981]],
#
#          ...,
#
#          [[ 0.2749]],
#
#          [[ 0.2439]],
#
#          [[-0.2101]]]], requires_grad=True)
# loop
# tensor([[[[-0.0678]],
#
#          [[-0.1767]],
#
#          [[ 1.3792]],
#
#          ...,
#
#          [[ 0.3175]],
#
#          [[ 0.1999]],
#
#          [[-0.5219]]]], requires_grad=True)
# loop
# tensor([[[[-0.2955]],
#
#          [[-0.3542]],
#
#          [[ 1.7899]],
#
#          ...,
#
#          [[ 0.3520]],
#
#          [[ 0.2373]],
#
#          [[-0.2856]]]], requires_grad=True)
# loop
# tensor([[[[-0.3624]],
#
#          [[-0.0955]],
#
#          [[ 0.5279]],
#
#          ...,
#
#          [[-0.0133]],
#
#          [[ 0.1462]],
#
#          [[ 0.0367]]]], requires_grad=True)
# loop
# tensor([[[[-0.2955]],
#
#          [[-0.3542]],
#
#          [[ 1.7899]],
#
#          ...,
#
#          [[ 0.3520]],
#
#          [[ 0.2373]],
#
#          [[-0.2856]]]], requires_grad=True)
# loop
# tensor([[[[-0.2052]],
#
#          [[-0.0486]],
#
#          [[ 1.4136]],
#
#          ...,
#
#          [[ 0.3188]],
#
#          [[-0.0022]],
#
#          [[-0.4638]]]], requires_grad=True)
# loop
# tensor([[[[-0.2955]],
#
#          [[-0.3542]],
#
#          [[ 1.7899]],
#
#          ...,
#
#          [[ 0.3520]],
#
#          [[ 0.2373]],
#
#          [[-0.2856]]]], requires_grad=True)
# loop
# tensor([[[[-0.2955]],
#
#          [[-0.3542]],
#
#          [[ 1.7899]],
#
#          ...,
#
#          [[ 0.3520]],
#
#          [[ 0.2373]],
#
#          [[-0.2856]]]], requires_grad=True)
# loop
# tensor([[[[-0.0202]],
#
#          [[ 0.0789]],
#
#          [[ 1.3981]],
#
#          ...,
#
#          [[ 0.2749]],
#
#          [[ 0.2439]],
#
#          [[-0.2101]]]], requires_grad=True)
# loop
# tensor([[[[-0.0678]],
#
#          [[-0.1767]],
#
#          [[ 1.3792]],
#
#          ...,
#
#          [[ 0.3175]],
#
#          [[ 0.1999]],
#
#          [[-0.5219]]]], requires_grad=True)
# loop
# tensor([[[[-0.2955]],
#
#          [[-0.3542]],
#
#          [[ 1.7899]],
#
#          ...,
#
#          [[ 0.3520]],
#
#          [[ 0.2373]],
#
#          [[-0.2856]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0560]],
#
#          [[-0.1855]],
#
#          [[ 0.7655]],
#
#          ...,
#
#          [[ 0.1070]],
#
#          [[ 0.2098]],
#
#          [[ 0.0928]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0368]],
#
#          [[ 0.2183]],
#
#          [[ 0.9872]],
#
#          ...,
#
#          [[ 0.1193]],
#
#          [[-0.0835]],
#
#          [[-0.2468]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0917]],
#
#          [[ 0.0097]],
#
#          [[ 0.7427]],
#
#          ...,
#
#          [[-0.2147]],
#
#          [[ 0.0941]],
#
#          [[-0.7452]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5676]],
#
#          [[-0.4052]],
#
#          [[ 0.4294]],
#
#          ...,
#
#          [[ 0.1461]],
#
#          [[ 0.1040]],
#
#          [[ 0.0538]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0368]],
#
#          [[ 0.2183]],
#
#          [[ 0.9872]],
#
#          ...,
#
#          [[ 0.1193]],
#
#          [[-0.0835]],
#
#          [[-0.2468]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1237]],
#
#          [[-0.0586]],
#
#          [[ 0.8315]],
#
#          ...,
#
#          [[-0.2189]],
#
#          [[ 0.0443]],
#
#          [[-0.0901]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1666]],
#
#          [[-0.0160]],
#
#          [[ 0.8017]],
#
#          ...,
#
#          [[-0.0576]],
#
#          [[ 0.0613]],
#
#          [[ 0.0322]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2436]],
#
#          [[-0.0614]],
#
#          [[ 0.6785]],
#
#          ...,
#
#          [[ 0.0439]],
#
#          [[ 0.0326]],
#
#          [[ 0.1904]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2144]],
#
#          [[-0.0058]],
#
#          [[ 0.6521]],
#
#          ...,
#
#          [[ 0.2752]],
#
#          [[ 0.1994]],
#
#          [[-0.2702]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1777]],
#
#          [[-0.1610]],
#
#          [[-0.0538]],
#
#          ...,
#
#          [[ 0.0104]],
#
#          [[ 0.2803]],
#
#          [[-0.0663]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1777]],
#
#          [[-0.1610]],
#
#          [[-0.0538]],
#
#          ...,
#
#          [[ 0.0104]],
#
#          [[ 0.2803]],
#
#          [[-0.0663]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1414]],
#
#          [[-0.5510]],
#
#          [[ 0.1895]],
#
#          ...,
#
#          [[ 0.1111]],
#
#          [[ 0.4417]],
#
#          [[-0.5195]]]], requires_grad=True)
# loop
# tensor([[[[ 0.0014]],
#
#          [[-0.2768]],
#
#          [[-0.4003]],
#
#          ...,
#
#          [[ 0.1805]],
#
#          [[ 0.2673]],
#
#          [[-0.0939]]]], requires_grad=True)
# loop
# tensor([[[[-0.2306]],
#
#          [[ 0.1743]],
#
#          [[-0.1151]],
#
#          ...,
#
#          [[-0.0369]],
#
#          [[ 0.2364]],
#
#          [[ 0.0229]]]], requires_grad=True)
# loop
# tensor([[[[-0.0508]],
#
#          [[ 0.3813]],
#
#          [[-0.9796]],
#
#          ...,
#
#          [[ 0.1766]],
#
#          [[ 0.1077]],
#
#          [[-0.8729]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2094]],
#
#          [[-0.6203]],
#
#          [[ 0.5018]],
#
#          ...,
#
#          [[ 0.1436]],
#
#          [[ 0.3527]],
#
#          [[-0.4745]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3167]],
#
#          [[-0.2032]],
#
#          [[ 0.2266]],
#
#          ...,
#
#          [[ 0.1952]],
#
#          [[ 0.2168]],
#
#          [[-0.4109]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2365]],
#
#          [[-0.4290]],
#
#          [[ 0.3436]],
#
#          ...,
#
#          [[ 0.1791]],
#
#          [[ 0.2833]],
#
#          [[-0.6403]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2094]],
#
#          [[-0.6203]],
#
#          [[ 0.5018]],
#
#          ...,
#
#          [[ 0.1436]],
#
#          [[ 0.3527]],
#
#          [[-0.4745]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3402]],
#
#          [[-0.6849]],
#
#          [[ 0.3065]],
#
#          ...,
#
#          [[ 0.2352]],
#
#          [[ 0.0778]],
#
#          [[-0.4348]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5079]],
#
#          [[-0.1835]],
#
#          [[ 0.5911]],
#
#          ...,
#
#          [[ 0.3965]],
#
#          [[-0.2572]],
#
#          [[-0.8754]]]], requires_grad=True)
# loop
# tensor([[[[ 0.3523]],
#
#          [[-0.2288]],
#
#          [[ 0.6938]],
#
#          ...,
#
#          [[ 0.1055]],
#
#          [[ 0.0512]],
#
#          [[-0.0205]]]], requires_grad=True)
# loop
# tensor([[[[ 0.5468]],
#
#          [[-0.8478]],
#
#          [[ 0.1099]],
#
#          ...,
#
#          [[ 0.3950]],
#
#          [[ 0.2534]],
#
#          [[-0.8070]]]], requires_grad=True)
# loop
# tensor([[[[-0.1120]],
#
#          [[-0.1166]],
#
#          [[ 0.0231]],
#
#          ...,
#
#          [[ 0.3648]],
#
#          [[ 0.2955]],
#
#          [[-0.7723]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2374]],
#
#          [[ 0.1126]],
#
#          [[ 0.2708]],
#
#          ...,
#
#          [[ 0.4046]],
#
#          [[ 0.1997]],
#
#          [[-0.6415]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4607]],
#
#          [[-0.1873]],
#
#          [[-0.8052]],
#
#          ...,
#
#          [[ 0.4251]],
#
#          [[ 0.3973]],
#
#          [[ 0.0564]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4607]],
#
#          [[-0.1873]],
#
#          [[-0.8052]],
#
#          ...,
#
#          [[ 0.4251]],
#
#          [[ 0.3973]],
#
#          [[ 0.0564]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4925]],
#
#          [[-0.1467]],
#
#          [[-0.2087]],
#
#          ...,
#
#          [[ 0.5035]],
#
#          [[ 0.3515]],
#
#          [[-0.1227]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4183]],
#
#          [[-0.0080]],
#
#          [[-1.0046]],
#
#          ...,
#
#          [[ 0.1834]],
#
#          [[ 0.2875]],
#
#          [[ 0.3411]]]], requires_grad=True)
# loop
# tensor([[[[ 0.7926]],
#
#          [[ 0.2006]],
#
#          [[-0.7690]],
#
#          ...,
#
#          [[ 0.2350]],
#
#          [[ 0.3616]],
#
#          [[-0.0453]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4607]],
#
#          [[-0.1873]],
#
#          [[-0.8052]],
#
#          ...,
#
#          [[ 0.4251]],
#
#          [[ 0.3973]],
#
#          [[ 0.0564]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4925]],
#
#          [[-0.1467]],
#
#          [[-0.2087]],
#
#          ...,
#
#          [[ 0.5035]],
#
#          [[ 0.3515]],
#
#          [[-0.1227]]]], requires_grad=True)
# loop
# tensor([[[[ 0.4183]],
#
#          [[-0.0080]],
#
#          [[-1.0046]],
#
#          ...,
#
#          [[ 0.1834]],
#
#          [[ 0.2875]],
#
#          [[ 0.3411]]]], requires_grad=True)
# loop
# tensor([[[[ 0.1693]],
#
#          [[ 0.1450]],
#
#          [[ 0.4322]],
#
#          ...,
#
#          [[ 0.2045]],
#
#          [[ 0.1793]],
#
#          [[-0.4713]]]], requires_grad=True)
# loop
# tensor([[[[ 0.2394]],
#
#          [[ 0.1630]],
#
#          [[ 1.0445]],
#
#          ...,
#
#          [[ 0.1899]],
#
#          [[ 0.0052]],
#
#          [[-0.7293]]]], requires_grad=True)
# loop
# tensor([[[[-0.1265]],
#
#          [[-0.0030]],
#
#          [[ 0.5069]],
#
#          ...,
#
#          [[ 0.4914]],
#
#          [[ 0.1046]],
#
#          [[-0.4528]]]], requires_grad=True)

# %%
import pandas as pd

df = pd.read_csv('/content/drive/MyDrive/Datasets/metricas/kitti_08_convnext_v1.csv')

# %%
from sklearn.metrics import RocCurveDisplay
import matplotlib.pyplot as plt


RocCurveDisplay.from_predictions(df['actual'], df['pred'])
plt.show()

# %%
from sklearn.metrics import roc_auc_score, accuracy_score, f1_score


print('AUC: ',roc_auc_score(df['actual'], df['pred']))
print('Accuracy: ',accuracy_score(df['actual'], df['pred']))
print('f1: ',f1_score(df['actual'], df['pred']))
# Out:
# AUC:  0.5035931330868153
# Accuracy:  0.8673218673218673
# f1:  0.07849829351535836

# %%
from sklearn.metrics import confusion_matrix

confusion_matrix(df['actual'], df['pred'])
# Out:
# array([[3507,  239],
#        [ 301,   23]])
